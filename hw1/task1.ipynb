# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxHolikov/DataScience/blob/main/hw1/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Создайте кортеж, содержащий 4 разных числа. Выведите на экран значение предпоследнего элемента кортежа (используя отрицательный индекс).

# %%
numbers_tuple = (1, 2, 3, 4)
print(numbers_tuple[-2])
# Out:
# 3
