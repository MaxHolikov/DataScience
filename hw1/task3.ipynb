# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxHolikov/DataScience/blob/main/hw1/task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.Создайте словарь, содержащий информацию о студенте: имя, возраст, курс, предметы (список). Выведите все предметы студента через запятую.

# %%
student = {
    "имя": "Иван",
    "возраст": 18,
    "курс": 1,
    "предметы": ["Математика", "Физика", "Программирование", "Микроэлектроника"]
}

# Вывод всех предметов через запятую
print(", ".join(student["предметы"]))
# Out:
# Математика, Физика, Программирование, Микроэлектроника
