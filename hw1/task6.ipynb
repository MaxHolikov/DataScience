# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxHolikov/DataScience/blob/main/hw1/task6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 6.Создайте два множества из 4 разных чисел каждое, найдите их пересечение и выведите на экран.

# %%
set_1 = {1, 3, 5, 6}
set_2 = {3, 6, 8, 10}

intersection = set_1 & set_2
print(f"Пересечение: {intersection}")
# Out:
# Пересечение: {3, 6}
