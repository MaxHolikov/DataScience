# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxHolikov/DataScience/blob/main/hw2/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#main.py
# Импортирует библиотеки для работ
import data_loader as dl
from data_processing import DataProcessing
from visual import Visual
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

file_path = 'titanic.csv'  # путь к CSV файлу
data = dl.load_data_csv(file_path)  #"https://api.example.com/data"

if data is None:
  print('ошибка загрузки')
else:
  print('Данные загружены')

processing = DataProcessing(data)
missing_values = processing.count_missing()
print(missing_values.sum())

vis = Visual(data)
vis.histogram ('whitegrid', 2, 4, 'Sex', 'Survived')
vis.histogram ('whitegrid', 9, 5, 'Age', 'Survived')
vis.histogram ('whitegrid', 9, 5, 'Pclass', 'Survived')

vis.boxplot('whitegrid', 9, 3, 'Fare', 'Pclass', 'h', -5, 300)
# Out:
# Загружено 887 строк из файла CSV
#
# Данные загружены
# 0
