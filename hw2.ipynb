# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxHolikov/DataScience/blob/main/hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#main.py
# Импортирует библиотеки для работы
import data_loger as dl
import data_preprocess as pre
from sklearn.model_selection import train_test_split



#Датасет: Анализ данных «Титаник»


# Загрузка данных
file_path = 'titanic.csv'  # Замените на путь к вашему CSV файлу
data = dl.load_data_csv(file_path)

'''
file_path = 'titanic.json'  # Замените на путь к вашему json файлу
data = dl.load_data_json(file_path)

# сделать API
'''
# Out:
# Данные загружены из CSV.
# "\nfile_path = 'titanic.json'  # Замените на путь к вашему json файлу\ndata = dl.load_data_json(file_path)\n\n# сделать API\n"

# %%
#main.py
# Импортирует библиотеки для работы
import data_loger as dl
import data_preprocess as pre
from sklearn.model_selection import train_test_split



#Датасет: Анализ данных «Титаник»


# Загрузка данных
file_path = 'titanic.csv'  # Замените на путь к вашему CSV файлу
data = dl.load_data_csv(file_path)

'''
file_path = 'titanic.json'  # Замените на путь к вашему json файлу
data = dl.load_data_json(file_path)

# сделать API
'''
# Out:
# Данные загружены из CSV.
# "\nfile_path = 'titanic.json'  # Замените на путь к вашему json файлу\ndata = dl.load_data_json(file_path)\n\n# сделать API\n"
