# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxHolikov/DataScience/blob/main/task1/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Создайте кортеж, содержащий 4 разных числа. Выведите на экран значение предпоследнего элемента кортежа (используя отрицательный индекс).

numbers_tuple = (1, 2, 3, 4)
print(numbers_tuple[-2])
# Out:
# 3

# %%
#2. Напишите программу, которая принимает строку от пользователя и выводит количество символов в этой строке без учета пробелов.
phrase = input()
text_after = phrase.replace(' ', '')
print(len(text_after))
# Out:
# w r r r y
# 5

# %%
#10. Создайте список из 5 строк и замените в нем каждый третий символ в каждой строке на звездочку '*'.
my_list = ['один', 'два', 'три', 'четыре', 'пять']
#for elem in my_list:
delimiter = ' '
output = delimiter.join(my_list)
print(output)
#lens=len(output)
print(output[2])
output[2]='*'
print(output)
#while i<len(output):
 # print(i)
j=0
#for i in range(len(output)):
#  if output[i]!= ' ':
#    if j==2:
#      output[i]= '*'
#  if  output[i]== ' ':
#    j=0
#  j=j+1
#print(output)
# Out:
# один два три четыре пять
# и
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-173408900.py in <cell line: 0>()
#       7 #lens=len(output)
#       8 print(output[2])
# ----> 9 output[2]='*'
#      10 print(output)
#      11 #while i<len(output):
#
# TypeError: 'str' object does not support item assignment
